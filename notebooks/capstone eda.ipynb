# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import xlrd

# %%
urlbase = 'https://www.pro-football-reference.com/teams/'
injuries = '_injuries.htm'

# %%
#create team base url's for webscraper to run through
arizona = 'crd/2011'
atlanta = 'atl/2011'
buffalo = 'buf/2011'
baltimore = 'rav/2011'
carolina = 'car/2011'
cincinnati = 'cin/2011'
cleveland = 'cle/2011'
chicago = 'chi/2011'
dallas = 'dal/2011'
denver = 'den/2011'
detroit = 'det/2011'
greenbay = 'gnb/2011'
houston = 'htx/2011'
indy = 'clt/2011'
kc = 'kan/2011'
lac = 'sdg/2011'
lar = 'ram/2011'
jacksonville = 'jax/2011'
miami = 'mia/2011'
minnesota = 'min/2011'
newengland = 'new/2011'
neworleans = 'nor/2011'
nyg = 'nyg/2011'
nyj = 'nyj/2011'
oakland = 'rai/2011'
philly = 'rai/2011'
sanfran = 'sfo/2011'
seattle = 'sea/2011'
pittsburgh = 'pit/2011'
tampabay = 'tam/2011'
tennessee = 'oti/2011'
washington = 'was/2011'

# %%
#import the injury data excel notebook and individual sheets as their own df's
arizona_df = pd.ExcelFile('../data/arizona.xlsx')
arizona_df1 = pd.read_excel(arizona_df, '2011')
arizona_df2 = pd.read_excel(arizona_df, '2012')
arizona_df3 = pd.read_excel(arizona_df, '2013')
arizona_df4 = pd.read_excel(arizona_df, '2014')
arizona_df5 = pd.read_excel(arizona_df, '2015')
arizona_df6 = pd.read_excel(arizona_df, '2016')
arizona_df7 = pd.read_excel(arizona_df, '2017')
arizona_df8 = pd.read_excel(arizona_df, '2018')
arizona_df9 = pd.read_excel(arizona_df, '2019')
arizona_df10 = pd.read_excel(arizona_df, '2020')

atlanta_df = pd.ExcelFile('../data/atlanta.xlsx')
atlanta_df1 = pd.read_excel(atlanta_df, '2011')
atlanta_df2 = pd.read_excel(atlanta_df, '2012')
atlanta_df3 = pd.read_excel(atlanta_df, '2013')
atlanta_df4 = pd.read_excel(atlanta_df, '2014')
atlanta_df5 = pd.read_excel(atlanta_df, '2015')
atlanta_df6 = pd.read_excel(atlanta_df, '2016')
atlanta_df7 = pd.read_excel(atlanta_df, '2017')
atlanta_df8 = pd.read_excel(atlanta_df, '2018')
atlanta_df9 = pd.read_excel(atlanta_df, '2019')
atlanta_df10 = pd.read_excel(atlanta_df, '2020')

baltimore_df = pd.ExcelFile('../data/baltimore.xlsx')
baltimore_df1 = pd.read_excel(baltimore_df, '2011')
baltimore_df2 = pd.read_excel(baltimore_df, '2012')
baltimore_df3 = pd.read_excel(baltimore_df, '2013')
baltimore_df4 = pd.read_excel(baltimore_df, '2014')
baltimore_df5 = pd.read_excel(baltimore_df, '2015')
baltimore_df6 = pd.read_excel(baltimore_df, '2016')
baltimore_df7 = pd.read_excel(baltimore_df, '2017')
baltimore_df8 = pd.read_excel(baltimore_df, '2018')
baltimore_df9 = pd.read_excel(baltimore_df, '2019')
baltimore_df10 = pd.read_excel(baltimore_df, '2020')

buffalo_df = pd.ExcelFile('../data/baltimore.xlsx')
buffalo_df1 = pd.read_excel(buffalo_df, '2011')
buffalo_df2 = pd.read_excel(buffalo_df, '2012')
buffalo_df3 = pd.read_excel(buffalo_df, '2013')
buffalo_df4 = pd.read_excel(buffalo_df, '2014')
buffalo_df5 = pd.read_excel(buffalo_df, '2015')
buffalo_df6 = pd.read_excel(buffalo_df, '2016')
buffalo_df7 = pd.read_excel(buffalo_df, '2017')
buffalo_df8 = pd.read_excel(buffalo_df, '2018')
buffalo_df9 = pd.read_excel(buffalo_df, '2019')
buffalo_df10 = pd.read_excel(buffalo_df, '2020')

carolina_df = pd.ExcelFile('../data/carolina.xlsx')
carolina_df1 = pd.read_excel(carolina_df, '2011')
carolina_df2 = pd.read_excel(carolina_df, '2012')
caroina_df3 = pd.read_excel(carolina_df, '2013')
carolina_df4 = pd.read_excel(carolina_df, '2014')
carolina_df5 = pd.read_excel(carolina_df, '2015')
carolina_df6 = pd.read_excel(carolina_df, '2016')
carolina_df7 = pd.read_excel(carolina_df, '2017')
carolina_df8 = pd.read_excel(carolina_df, '2018')
carolina_df9 = pd.read_excel(carolina_df, '2019')
carolina_df10 = pd.read_excel(carolina_df, '2020')

chargers_df = pd.ExcelFile('../data/chargers.xlsx')
chargers_df1 = pd.read_excel(chargers_df, '2011')
chargers_df2 = pd.read_excel(chargers_df, '2012')
chargers_df3 = pd.read_excel(chargers_df, '2013')
chargers_df4 = pd.read_excel(chargers_df, '2014')
chargers_df5 = pd.read_excel(chargers_df, '2015')
chargers_df6 = pd.read_excel(chargers_df, '2016')
chargers_df7 = pd.read_excel(chargers_df, '2017')
chargers_df8 = pd.read_excel(chargers_df, '2018')
chargers_df9 = pd.read_excel(chargers_df, '2019')
chargers_df10 = pd.read_excel(chargers_df, '2020')

chicago_df = pd.ExcelFile('../data/chicago.xlsx')
chicago_df1 = pd.read_excel(chicago_df, '2011')
chicago_df2 = pd.read_excel(chicago_df, '2012')
chicago_df3 = pd.read_excel(chicago_df, '2013')
chicago_df4 = pd.read_excel(chicago_df, '2014')
chicago_df5 = pd.read_excel(chicago_df, '2015')
chicago_df6 = pd.read_excel(chicago_df, '2016')
chicago_df7 = pd.read_excel(chicago_df, '2017')
chicago_df8 = pd.read_excel(chicago_df, '2018')
chicago_df9 = pd.read_excel(chicago_df, '2019')
chicago_df10 = pd.read_excel(chicago_df, '2020')

cincinatti_df = pd.ExcelFile('../data/cincinatti.xlsx')
cincinatti_df1 = pd.read_excel(cincinatti_df, '2011')
cincinatti_df2 = pd.read_excel(cincinatti_df, '2012')
cincinatti_df3 = pd.read_excel(cincinatti_df, '2013')
cincinatti_df4 = pd.read_excel(cincinatti_df, '2014')
cincinatti_df5 = pd.read_excel(cincinatti_df, '2015')
cincinatti_df6 = pd.read_excel(cincinatti_df, '2016')
cincinatti_df7 = pd.read_excel(cincinatti_df, '2017')
cincinatti_df8 = pd.read_excel(cincinatti_df, '2018')
cincinatti_df9 = pd.read_excel(cincinatti_df, '2019')
cincinatti_df10 = pd.read_excel(cincinatti_df, '2020')

cleveland_df = pd.ExcelFile('../data/cleveland.xlsx')
cleveland_df1 = pd.read_excel(cleveland_df, '2011')
cleveland_df2 = pd.read_excel(cleveland_df, '2012')
cleveland_df3 = pd.read_excel(cleveland_df, '2013')
cleveland_df4 = pd.read_excel(cleveland_df, '2014')
cleveland_df5 = pd.read_excel(cleveland_df, '2015')
cleveland_df6 = pd.read_excel(cleveland_df, '2016')
cleveland_df7 = pd.read_excel(cleveland_df, '2017')
cleveland_df8 = pd.read_excel(cleveland_df, '2018')
cleveland_df9 = pd.read_excel(cleveland_df, '2019')
cleveland_df10 = pd.read_excel(cleveland_df, '2020')

dallas_df = pd.ExcelFile('../data/dallas.xlsx')
dallas_df1 = pd.read_excel(dallas_df, '2011')
dallas_df2 = pd.read_excel(dallas_df, '2012')
dallas_df3 = pd.read_excel(dallas_df, '2013')
dallas_df4 = pd.read_excel(dallas_df, '2014')
dallas_df5 = pd.read_excel(dallas_df, '2015')
dallas_df6 = pd.read_excel(dallas_df, '2016')
dallas_df7 = pd.read_excel(dallas_df, '2017')
dallas_df8 = pd.read_excel(dallas_df, '2018')
dallas_df9 = pd.read_excel(dallas_df, '2019')
dallas_df10 = pd.read_excel(dallas_df, '2020')

denver = pd.ExcelFile('../data/denver.xlsx')
denver1 = pd.read_excel(denver, '2011')
denver2 = pd.read_excel(denver, '2012')
denver3 = pd.read_excel(denver, '2013')
denver4 = pd.read_excel(denver, '2014')
denver5 = pd.read_excel(denver, '2015')
denver6 = pd.read_excel(denver, '2016')
denver7 = pd.read_excel(denver, '2017')
denver8 = pd.read_excel(denver, '2018')
denver9 = pd.read_excel(denver, '2019')
denver10 = pd.read_excel(denver, '2020')

detroit = pd.ExcelFile('../data/detroit.xlsx')
detroit1 = pd.read_excel(detroit, '2011')
detroit2 = pd.read_excel(detroit, '2012')
detroit3 = pd.read_excel(detroit, '2013')
detroit4 = pd.read_excel(detroit, '2014')
detroit5 = pd.read_excel(detroit, '2015')
detroit6 = pd.read_excel(detroit, '2016')
detroit7 = pd.read_excel(detroit, '2017')
detroit8 = pd.read_excel(detroit, '2018')
detroit9 = pd.read_excel(detroit, '2019')
detroit10 = pd.read_excel(detroit, '2020')

greenbay = pd.ExcelFile('../data/greenbay.xlsx')
greenbay1 = pd.read_excel(greenbay, '2011')
greenbay2 = pd.read_excel(greenbay, '2012')
greenbay3 = pd.read_excel(greenbay, '2013')
greenbay4 = pd.read_excel(greenbay, '2014')
greenbay5 = pd.read_excel(greenbay, '2015')
greenbay6 = pd.read_excel(greenbay, '2016')
greenbay7 = pd.read_excel(greenbay, '2017')
greenbay8 = pd.read_excel(greenbay, '2018')
greenbay9 = pd.read_excel(greenbay, '2019')
greenbay10 = pd.read_excel(greenbay, '2020')

houston = pd.ExcelFile('../data/houston.xlsx')
houston1 = pd.read_excel(houston, '2011')
houston2 = pd.read_excel(houston, '2012')
houston3 = pd.read_excel(houston, '2013')
houston4 = pd.read_excel(houston, '2014')
houston5 = pd.read_excel(houston, '2015')
houston6 = pd.read_excel(houston, '2016')
houston7 = pd.read_excel(houston, '2017')
houston8 = pd.read_excel(houston, '2018')
houston9 = pd.read_excel(houston, '2019')
houston10 = pd.read_excel(houston, '2020')

indy = pd.ExcelFile('../data/indy.xlsx')
indy1 = pd.read_excel(indy, '2011')
indy2 = pd.read_excel(indy, '2012')
indy3 = pd.read_excel(indy, '2013')
indy4 = pd.read_excel(indy, '2014')
indy5 = pd.read_excel(indy, '2015')
indy6 = pd.read_excel(indy, '2016')
indy7 = pd.read_excel(indy, '2017')
indy8 = pd.read_excel(indy, '2018')
indy9 = pd.read_excel(indy, '2019')
indy10 = pd.read_excel(indy, '2020')

jacksonville = pd.ExcelFile('../data/jacksonville.xlsx')
jacksonville1 = pd.read_excel(jacksonville, '2011')
jacksonville2 = pd.read_excel(jacksonville, '2012')
jacksonville3 = pd.read_excel(jacksonville, '2013')
jacksonville4 = pd.read_excel(jacksonville, '2014')
jacksonville5 = pd.read_excel(jacksonville, '2015')
jacksonville6 = pd.read_excel(jacksonville, '2016')
jacksonville7 = pd.read_excel(jacksonville, '2017')
jacksonville8 = pd.read_excel(jacksonville, '2018')
jacksonville9 = pd.read_excel(jacksonville, '2019')
jacksonville10 = pd.read_excel(jacksonville, '2020')

kansascity = pd.ExcelFile('../data/kansascity.xlsx')
kansascity1 = pd.read_excel(kansascity, '2011')
kansascity2 = pd.read_excel(kansascity, '2012')
kansascity3 = pd.read_excel(kansascity, '2013')
kansascity4 = pd.read_excel(kansascity, '2014')
kansascity5 = pd.read_excel(kansascity, '2015')
kansascity6 = pd.read_excel(kansascity, '2016')
kansascity7 = pd.read_excel(kansascity, '2017')
kansascity8 = pd.read_excel(kansascity, '2018')
kansascity9 = pd.read_excel(kansascity, '2019')
kansascity10 = pd.read_excel(kansascity, '2020')

miami = pd.ExcelFile('../data/miami.xlsx')
miami1 = pd.read_excel(miami, '2011')
miami2 = pd.read_excel(miami, '2012')
miami3 = pd.read_excel(miami, '2013')
miami4 = pd.read_excel(miami, '2014')
miami5 = pd.read_excel(miami, '2015')
miami6 = pd.read_excel(miami, '2016')
miami7 = pd.read_excel(miami, '2017')
miami8 = pd.read_excel(miami, '2018')
miami9 = pd.read_excel(miami, '2019')
miami10 = pd.read_excel(miami, '2020')

minnesota = pd.ExcelFile('../data/minnesota.xlsx')
minnesota1 = pd.read_excel(minnesota, '2011')
minnesota2 = pd.read_excel(minnesota, '2012')
minnesota3 = pd.read_excel(minnesota, '2013')
minnesota4 = pd.read_excel(minnesota, '2014')
minnesota5 = pd.read_excel(minnesota, '2015')
minnesota6 = pd.read_excel(minnesota, '2016')
minnesota7 = pd.read_excel(minnesota, '2017')
minnesota8 = pd.read_excel(minnesota, '2018')
minnesota9 = pd.read_excel(minnesota, '2019')
minnesota10 = pd.read_excel(minnesota, '2020')

newengland = pd.ExcelFile('../data/newengland.xlsx')
newengland1 = pd.read_excel(newengland, '2011')
newengland2 = pd.read_excel(newengland, '2012')
newengland3 = pd.read_excel(newengland, '2013')
newengland4 = pd.read_excel(newengland, '2014')
newengland5 = pd.read_excel(newengland, '2015')
newengland6 = pd.read_excel(newengland, '2016')
newengland7 = pd.read_excel(newengland, '2017')
newengland8 = pd.read_excel(newengland, '2018')
newengland9 = pd.read_excel(newengland, '2019')
newengland10 = pd.read_excel(newengland, '2020')

neworleans = pd.ExcelFile('../data/neworleans.xlsx')
neworleans1 = pd.read_excel(neworleans, '2011')
neworleans2 = pd.read_excel(neworleans, '2012')
neworleans3 = pd.read_excel(neworleans, '2013')
neworleans4 = pd.read_excel(neworleans, '2014')
neworleans5 = pd.read_excel(neworleans, '2015')
neworleans6 = pd.read_excel(neworleans, '2016')
neworleans7 = pd.read_excel(neworleans, '2017')
neworleans8 = pd.read_excel(neworleans, '2018')
neworleans9 = pd.read_excel(neworleans, '2019')
neworleans10 = pd.read_excel(neworleans, '2020')

nyg = pd.ExcelFile('../data/nyg.xlsx')
nyg1 = pd.read_excel(nyg, '2011')
nyg2 = pd.read_excel(nyg, '2012')
nyg3 = pd.read_excel(nyg, '2013')
nyg4 = pd.read_excel(nyg, '2014')
nyg5 = pd.read_excel(nyg, '2015')
nyg6 = pd.read_excel(nyg, '2016')
nyg7 = pd.read_excel(nyg, '2017')
nyg8 = pd.read_excel(nyg, '2018')
nyg9 = pd.read_excel(nyg, '2019')
nyg10 = pd.read_excel(nyg, '2020')

nyj = pd.ExcelFile('../data/nyj.xlsx')
nyj1 = pd.read_excel(nyj, '2011')
nyj2 = pd.read_excel(nyj, '2012')
nyj3 = pd.read_excel(nyj, '2013')
nyj4 = pd.read_excel(nyj, '2014')
nyj5 = pd.read_excel(nyj, '2015')
nyj6 = pd.read_excel(nyj, '2016')
nyj7 = pd.read_excel(nyj, '2017')
nyj8 = pd.read_excel(nyj, '2018')
nyj9 = pd.read_excel(nyj, '2019')
nyj10 = pd.read_excel(nyj, '2020')

oakland = pd.ExcelFile('../data/oakland.xlsx')
oakland1 = pd.read_excel(oakland, '2011')
oakland2 = pd.read_excel(oakland, '2012')
oakland3 = pd.read_excel(oakland, '2013')
oakland4 = pd.read_excel(oakland, '2014')
oakland5 = pd.read_excel(oakland, '2015')
oakland6 = pd.read_excel(oakland, '2016')
oakland7 = pd.read_excel(oakland, '2017')
oakland8 = pd.read_excel(oakland, '2018')
oakland9 = pd.read_excel(oakland, '2019')
oakland10 = pd.read_excel(oakland, '2020')

oakland = pd.ExcelFile('../data/oakland.xlsx')
oakland1 = pd.read_excel(oakland, '2011')
oakland2 = pd.read_excel(oakland, '2012')
oakland3 = pd.read_excel(oakland, '2013')
oakland4 = pd.read_excel(oakland, '2014')
oakland5 = pd.read_excel(oakland, '2015')
oakland6 = pd.read_excel(oakland, '2016')
oakland7 = pd.read_excel(oakland, '2017')
oakland8 = pd.read_excel(oakland, '2018')
oakland9 = pd.read_excel(oakland, '2019')
oakland10 = pd.read_excel(oakland, '2020')

philadelphia = pd.ExcelFile('../data/philadelphia.xlsx')
philadelphia1 = pd.read_excel(philadelphia, '2011')
philadelphia2 = pd.read_excel(philadelphia, '2012')
philadelphia3 = pd.read_excel(philadelphia, '2013')
philadelphia4 = pd.read_excel(philadelphia, '2014')
philadelphia5 = pd.read_excel(philadelphia, '2015')
philadelphia6 = pd.read_excel(philadelphia, '2016')
philadelphia7 = pd.read_excel(philadelphia, '2017')
philadelphia8 = pd.read_excel(philadelphia, '2018')
philadelphia9 = pd.read_excel(philadelphia, '2019')
philadelphia10 = pd.read_excel(philadelphia, '2020')

pittsburgh = pd.ExcelFile('../data/pittsburgh.xlsx')
pittsburgh1 = pd.read_excel(pittsburgh, '2011')
pittsburgh2 = pd.read_excel(pittsburgh, '2012')
pittsburgh3 = pd.read_excel(pittsburgh, '2013')
pittsburgh4 = pd.read_excel(pittsburgh, '2014')
pittsburgh5 = pd.read_excel(pittsburgh, '2015')
pittsburgh6 = pd.read_excel(pittsburgh, '2016')
pittsburgh7 = pd.read_excel(pittsburgh, '2017')
pittsburgh8 = pd.read_excel(pittsburgh, '2018')
pittsburgh9 = pd.read_excel(pittsburgh, '2019')
pittsburgh10 = pd.read_excel(pittsburgh, '2020')

rams = pd.ExcelFile('../data/rams.xlsx')
rams1 = pd.read_excel(rams, '2011')
rams2 = pd.read_excel(rams, '2012')
rams3 = pd.read_excel(rams, '2013')
rams4 = pd.read_excel(rams, '2014')
rams5 = pd.read_excel(rams, '2015')
rams6 = pd.read_excel(rams, '2016')
rams7 = pd.read_excel(rams, '2017')
rams8 = pd.read_excel(rams, '2018')
rams9 = pd.read_excel(rams, '2019')
rams10 = pd.read_excel(rams, '2020')

redskins = pd.ExcelFile('../data/redskins.xlsx')
redskins1 = pd.read_excel(redskins, '2011')
redskins2 = pd.read_excel(redskins, '2012')
redskins3 = pd.read_excel(redskins, '2013')
redskins4 = pd.read_excel(redskins, '2014')
redskins5 = pd.read_excel(redskins, '2015')
redskins6 = pd.read_excel(redskins, '2016')
redskins7 = pd.read_excel(redskins, '2017')
redskins8 = pd.read_excel(redskins, '2018')
redskins9 = pd.read_excel(redskins, '2019')
redskins10 = pd.read_excel(redskins, '2020')

sanfran = pd.ExcelFile('../data/sanfran.xlsx')
sanfran1 = pd.read_excel(sanfran, '2011')
sanfran2 = pd.read_excel(sanfran, '2012')
sanfran3 = pd.read_excel(sanfran, '2013')
sanfran4 = pd.read_excel(sanfran, '2014')
sanfran5 = pd.read_excel(sanfran, '2015')
sanfran6 = pd.read_excel(sanfran, '2016')
sanfran7 = pd.read_excel(sanfran, '2017')
sanfran8 = pd.read_excel(sanfran, '2018')
sanfran9 = pd.read_excel(sanfran, '2019')
sanfran10 = pd.read_excel(sanfran, '2020')

seattle = pd.ExcelFile('../data/seattle.xlsx')
seattle1 = pd.read_excel(seattle, '2011')
seattle2 = pd.read_excel(seattle, '2012')
seattle3 = pd.read_excel(seattle, '2013')
seattle4 = pd.read_excel(seattle, '2014')
seattle5 = pd.read_excel(seattle, '2015')
seattle6 = pd.read_excel(seattle, '2016')
seattle7 = pd.read_excel(seattle, '2017')
seattle8 = pd.read_excel(seattle, '2018')
seattle9 = pd.read_excel(seattle, '2019')
seattle10 = pd.read_excel(seattle, '2020')

tampabay = pd.ExcelFile('../data/tampabay.xlsx')
tampabay1 = pd.read_excel(tampabay, '2011')
tampabay2 = pd.read_excel(tampabay, '2012')
tampabay3 = pd.read_excel(tampabay, '2013')
tampabay4 = pd.read_excel(tampabay, '2014')
tampabay5 = pd.read_excel(tampabay, '2015')
tampabay6 = pd.read_excel(tampabay, '2016')
tampabay7 = pd.read_excel(tampabay, '2017')
tampabay8 = pd.read_excel(tampabay, '2018')
tampabay9 = pd.read_excel(tampabay, '2019')
tampabay10 = pd.read_excel(tampabay, '2020')

tennessee = pd.ExcelFile('../data/tennessee.xlsx')
tennessee1 = pd.read_excel(tennessee, '2011')
tennessee2 = pd.read_excel(tennessee, '2012')
tennessee3 = pd.read_excel(tennessee, '2013')
tennessee4 = pd.read_excel(tennessee, '2014')
tennessee5 = pd.read_excel(tennessee, '2015')
tennessee6 = pd.read_excel(tennessee, '2016')
tennessee7 = pd.read_excel(tennessee, '2017')
tennessee8 = pd.read_excel(tennessee, '2018')
tennessee9 = pd.read_excel(tennessee, '2019')
tennessee10 = pd.read_excel(tennessee, '2020')

washington = pd.ExcelFile('../data/washington.xlsx')
washington5 = pd.read_excel(washington, '2015')
washington6 = pd.read_excel(washington, '2016')
washington7 = pd.read_excel(washington, '2017')
washington8 = pd.read_excel(washington, '2018')
washington9 = pd.read_excel(washington, '2019')
washington10 = pd.read_excel(washington, '2020')

# %%
washington10.head()
# Out:
#          Player  09/13vs. PHI 09/20vs. ARI 09/27vs. CLE 10/04vs. BAL  \
# 0     Kyle Allen          NaN          NaN          NaN          NaN
# 1  Ryan Anderson          NaN          NaN          NaN            Q
# 2     Jeff Badet          NaN          NaN          NaN          NaN
# 3   Marcus Baugh          NaN          NaN          NaN          NaN
# 4       Ryan Bee           IR           IR          NaN          NaN
#
#   10/11vs. LAR 10/18vs. NYG 10/25vs. DAL 11/08vs. NYG 11/15vs. DET  \
# 0          NaN          NaN          NaN          NaN            O
# 1          NaN            Q          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN            Q
# 3            O          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   11/22vs. CIN 11/26vs. DAL 12/07vs. PIT 12/13vs. SFO 12/20vs. SEA
# 0           IR           IR           IR           IR           IR
# ...

# %%
#Import the player position and salary notebooks
ari = pd.ExcelFile('../data/ari.xlsx')
ari1 = pd.read_excel(ari, '2015')
ari2 = pd.read_excel(ari, '2016')
ari3 = pd.read_excel(ari, '2017')
ari4 = pd.read_excel(ari, '2018')
ari5 = pd.read_excel(ari, '2019')
ari6 = pd.read_excel(ari, '2020')

atl = pd.ExcelFile('../data/atl.xlsx')
atl1 = pd.read_excel(atl, '2015')
atl2 = pd.read_excel(atl, '2016')
atl3 = pd.read_excel(atl, '2017')
atl4 = pd.read_excel(atl, '2018')
atl5 = pd.read_excel(atl, '2019')
atl6 = pd.read_excel(atl, '2020')


bal = pd.ExcelFile('../data/bal.xlsx')
bal1 = pd.read_excel(bal, '2015')
bal2 = pd.read_excel(bal, '2016')
bal3 = pd.read_excel(bal, '2017')
bal4 = pd.read_excel(bal, '2018')
bal5 = pd.read_excel(bal, '2019')
bal6 = pd.read_excel(bal, '2020')

buf = pd.ExcelFile('../data/buf.xlsx')
buf1 = pd.read_excel(buf, '2015')
buf2 = pd.read_excel(buf, '2016')
buf3 = pd.read_excel(buf, '2017')
buf4 = pd.read_excel(buf, '2018')
buf5 = pd.read_excel(buf, '2019')
buf6 = pd.read_excel(buf, '2020')

car = pd.ExcelFile('../data/car.xlsx')
car1 = pd.read_excel(car, '2015')
car2 = pd.read_excel(car, '2016')
car3 = pd.read_excel(car, '2017')
car4 = pd.read_excel(car, '2018')
car5 = pd.read_excel(car, '2019')
car6 = pd.read_excel(car, '2020')

sdg = pd.ExcelFile('../data/sdg.xlsx')
sdg1 = pd.read_excel(sdg, '2015')
sdg2 = pd.read_excel(sdg, '2016')
sdg3 = pd.read_excel(sdg, '2017')
sdg4 = pd.read_excel(sdg, '2018')
sdg5 = pd.read_excel(sdg, '2019')
sdg6 = pd.read_excel(sdg, '2020')

chi = pd.ExcelFile('../data/chi.xlsx')
chi1 = pd.read_excel(chi, '2015')
chi2 = pd.read_excel(chi, '2016')
chi3 = pd.read_excel(chi, '2017')
chi4 = pd.read_excel(chi, '2018')
chi5 = pd.read_excel(chi, '2019')
chi6 = pd.read_excel(chi, '2020')

cle = pd.ExcelFile('../data/cle.xlsx')
cle1 = pd.read_excel(cle, '2015')
cle2 = pd.read_excel(cle, '2016')
cle3 = pd.read_excel(cle, '2017')
cle4 = pd.read_excel(cle, '2018')
cle5 = pd.read_excel(cle, '2019')
cle6 = pd.read_excel(cle, '2020')

clt = pd.ExcelFile('../data/clt.xlsx')
clt1 = pd.read_excel(clt, '2015')
clt2 = pd.read_excel(clt, '2016')
clt3 = pd.read_excel(clt, '2017')
clt4 = pd.read_excel(clt, '2018')
clt5 = pd.read_excel(clt, '2019')
clt6 = pd.read_excel(clt, '2020')

dal = pd.ExcelFile('../data/dal.xlsx')
dal1 = pd.read_excel(dal, '2015')
dal2 = pd.read_excel(dal, '2016')
dal3 = pd.read_excel(dal, '2017')
dal4 = pd.read_excel(dal, '2018')
dal5 = pd.read_excel(dal, '2019')
dal6 = pd.read_excel(dal, '2020')

den = pd.ExcelFile('../data/den.xlsx')
den1 = pd.read_excel(den, '2015')
den2 = pd.read_excel(den, '2016')
den3 = pd.read_excel(den, '2017')
den4 = pd.read_excel(den, '2018')
den5 = pd.read_excel(den, '2019')
den6 = pd.read_excel(den, '2020')


det = pd.ExcelFile('../data/det.xlsx')
det1 = pd.read_excel(det, '2015')
det2 = pd.read_excel(det, '2016')
det3 = pd.read_excel(det, '2017')
det4 = pd.read_excel(det, '2018')
det5 = pd.read_excel(det, '2019')
det6 = pd.read_excel(det, '2020')

gnb = pd.ExcelFile('../data/gnb.xlsx')
gnb1 = pd.read_excel(gnb, '2015')
gnb2 = pd.read_excel(gnb, '2016')
gnb3 = pd.read_excel(gnb, '2017')
gnb4 = pd.read_excel(gnb, '2018')
gnb5 = pd.read_excel(gnb, '2019')
gnb6 = pd.read_excel(gnb, '2020')

htx = pd.ExcelFile('../data/htx.xlsx')
htx1 = pd.read_excel(htx, '2015')
htx2 = pd.read_excel(htx, '2016')
htx3 = pd.read_excel(htx, '2017')
htx4 = pd.read_excel(htx, '2018')
htx5 = pd.read_excel(htx, '2019')
htx6 = pd.read_excel(htx, '2020')


jax = pd.ExcelFile('../data/jax.xlsx')
jax1 = pd.read_excel(jax, '2015')
jax2 = pd.read_excel(jax, '2016')
jax3 = pd.read_excel(jax, '2017')
jax4 = pd.read_excel(jax, '2018')
jax5 = pd.read_excel(jax, '2019')
jax6 = pd.read_excel(jax, '2020')


kan = pd.ExcelFile('../data/kan.xlsx')
kan1 = pd.read_excel(kan, '2015')
kan2 = pd.read_excel(kan, '2016')
kan3 = pd.read_excel(kan, '2017')
kan4 = pd.read_excel(kan, '2018')
kan5 = pd.read_excel(kan, '2019')
kan6 = pd.read_excel(kan, '2020')

mia = pd.ExcelFile('../data/mia.xlsx')
mia1 = pd.read_excel(mia, '2015')
mia2 = pd.read_excel(mia, '2016')
mia3 = pd.read_excel(mia, '2017')
mia4 = pd.read_excel(mia, '2018')
mia5 = pd.read_excel(mia, '2019')
mia6 = pd.read_excel(mia, '2020')

minn = pd.ExcelFile('../data/minn.xlsx')
minn1 = pd.read_excel(minn, '2015')
minn2 = pd.read_excel(minn, '2016')
minn3 = pd.read_excel(minn, '2017')
minn4 = pd.read_excel(minn, '2018')
minn5 = pd.read_excel(minn, '2019')
minn6 = pd.read_excel(minn, '2020')

new = pd.ExcelFile('../data/new.xlsx')
new1 = pd.read_excel(new, '2015')
new2 = pd.read_excel(new, '2016')
new3 = pd.read_excel(new, '2017')
new4 = pd.read_excel(new, '2018')
new5 = pd.read_excel(new, '2019')
new6 = pd.read_excel(new, '2020')

nyj_positions = pd.ExcelFile('../data/nyj_positions.xlsx')
nyj_positions1 = pd.read_excel(nyj_positions, '2015')
nyj_positions2 = pd.read_excel(nyj_positions, '2016')
nyj_positions3 = pd.read_excel(nyj_positions, '2017')
nyj_positions4 = pd.read_excel(nyj_positions, '2018')
nyj_positions5 = pd.read_excel(nyj_positions, '2019')
nyj_positions6 = pd.read_excel(nyj_positions, '2020')

nyg_positions = pd.ExcelFile('../data/nyg_positions.xlsx')
nyg_positions1 = pd.read_excel(nyg_positions, '2015')
nyg_positions2 = pd.read_excel(nyg_positions, '2016')
nyg_positions3 = pd.read_excel(nyg_positions, '2017')
nyg_positions4 = pd.read_excel(nyg_positions, '2018')
nyg_positions5 = pd.read_excel(nyg_positions, '2019')
nyg_positions6 = pd.read_excel(nyg_positions, '2020')


pit = pd.ExcelFile('../data/pit.xlsx')
pit1 = pd.read_excel(pit, '2015')
pit2 = pd.read_excel(pit, '2016')
pit3 = pd.read_excel(pit, '2017')
pit4 = pd.read_excel(pit, '2018')
pit5 = pd.read_excel(pit, '2019')
pit6 = pd.read_excel(pit, '2020')

rai = pd.ExcelFile('../data/rai.xlsx')
rai1 = pd.read_excel(rai, '2015')
rai2 = pd.read_excel(rai, '2016')
rai3 = pd.read_excel(rai, '2017')
rai4 = pd.read_excel(rai, '2018')
rai5 = pd.read_excel(rai, '2019')
rai6 = pd.read_excel(rai, '2020')

ram = pd.ExcelFile('../data/ram.xlsx')
ram1 = pd.read_excel(ram, '2015')
ram2 = pd.read_excel(ram, '2016')
ram3 = pd.read_excel(ram, '2017')
ram4 = pd.read_excel(ram, '2018')
ram5 = pd.read_excel(ram, '2019')
ram6 = pd.read_excel(ram, '2020')

sdg = pd.ExcelFile('../data/sdg.xlsx')
sdg1 = pd.read_excel(sdg, '2015')
sdg2 = pd.read_excel(sdg, '2016')
sdg3 = pd.read_excel(sdg, '2017')
sdg4 = pd.read_excel(sdg, '2018')
sdg5 = pd.read_excel(sdg, '2019')
sdg6 = pd.read_excel(sdg, '2020')

sea = pd.ExcelFile('../data/sea.xlsx')
sea1 = pd.read_excel(sea, '2015')
sea2 = pd.read_excel(sea, '2016')
sea3 = pd.read_excel(sea, '2017')
sea4 = pd.read_excel(sea, '2018')
sea5 = pd.read_excel(sea, '2019')
sea6 = pd.read_excel(sea, '2020')

sfo = pd.ExcelFile('../data/sfo.xlsx')
sfo1 = pd.read_excel(sfo, '2015')
sfo2 = pd.read_excel(sfo, '2016')
sfo3 = pd.read_excel(sfo, '2017')
sfo4 = pd.read_excel(sfo, '2018')
sfo5 = pd.read_excel(sfo, '2019')
sfo6 = pd.read_excel(sfo, '2020')

tam = pd.ExcelFile('../data/tam.xlsx')
tam1 = pd.read_excel(tam, '2015')
tam2 = pd.read_excel(tam, '2016')
tam3 = pd.read_excel(tam, '2017')
tam4 = pd.read_excel(tam, '2018')
tam5 = pd.read_excel(tam, '2019')
tam6 = pd.read_excel(tam, '2020')

ten = pd.ExcelFile('../data/ten.xlsx')
ten1 = pd.read_excel(ten, '2015')
ten2 = pd.read_excel(ten, '2016')
ten3 = pd.read_excel(ten, '2017')
ten4 = pd.read_excel(ten, '2018')
ten5 = pd.read_excel(ten, '2019')
ten6 = pd.read_excel(ten, '2020')

was = pd.ExcelFile('../data/was.xlsx')
was1 = pd.read_excel(was, '2015')
was2 = pd.read_excel(was, '2016')
was3 = pd.read_excel(was, '2017')
was4 = pd.read_excel(was, '2018')
was5 = pd.read_excel(was, '2019')
was6 = pd.read_excel(was, '2020')

# %%
was3.head()
# Out:
#    No.        Player   Age Pos   G  GS   Wt         Ht  College/Univ  \
# 0    8   Kirk Cousins   29  QB  16  16  202 2020-06-03  Michigan St.
# 1   32  Samaje Perine   22  RB  16   8  240 2020-05-11      Oklahoma
# 2   20  Robert Kelley   25  rb   7   7  229 2000-06-01        Tulane
# 3   14     Ryan Grant   27  wr  16   7  195 2000-06-01        Tulane
# 4   18   Josh Doctson   25  WR  16  14  205 2020-06-02   TCU,Wyoming
#
#    BirthDate   Yrs  AV                            Drafted (tm/rnd/yr)  \
# 0 1988-08-19     5  12  Washington Redskins / 4th / 102nd pick / 2012
# 1 1995-09-16  Rook   5  Washington Redskins / 4th / 114th pick / 2017
# 2 1992-10-03     1   1                                            NaN
# 3 1990-12-19     3   4  Washington Redskins / 5th / 142nd pick / 2014
# 4 1992-12-03     1   4   Washington Redskins / 1st / 22nd pick / 2016
#
#      Salary
# 0  23943600
# 1    465000
# 2    540000
# 3    690000
# 4    906802

# %%
tennessee4 = tennessee4.rename(columns={"09/07vs. KAN": "week_1", "09/14vs. DAL": "week 2", "09/21vs. CIN":"week 3", "09/28vs. IND":"week 4", "10/05vs. CLE" : "week 5", "10/12vs. JAX" : "week 6", "10/19vs. WAS" : "week 7", "10/26vs. HOU" : "week 8", "11/09vs. BAL" : "week 9", "11/17vs. PIT" : "week 10", "11/23vs. PHI" : "week 11", "11/30vs. HOU" : "week 12", "12/07vs. NYG" : "week 13", "12/14vs. NYJ" : "week 14", "12/18vs. JAX" : "week 15", "12/28vs. IND" : "week 16"})
tennessee4
# Out:
#                Player  week_1 week 2 week 3 week 4 week 5 week 6 week 7  \
# 0       James Anderson    NaN    NaN    NaN      P    NaN    NaN    NaN
# 1        Jackie Battle      P      P    NaN    NaN    NaN    NaN    NaN
# 2       Brett Brackett    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3           Zach Brown      Q      O     IR     IR     IR     IR     IR
# 4        Jurrell Casey    NaN    NaN    NaN    NaN      P    NaN    NaN
# 5        Zaviar Gooden    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6         Shonn Greene    NaN    NaN    NaN    NaN    NaN      D      D
# 7      Michael Griffin    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8       Quentin Groves    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9      Sammie Lee Hill    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10     Marqueston Huff    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11       Justin Hunter    NaN      P    NaN    NaN    NaN    NaN    NaN
# ...

# %%
rams7.head()
# Out:
#              Player  09/10vs. IND 09/17vs. WAS 09/21vs. SFO 10/01vs. DAL  \
# 0  Maurice Alexander          NaN          NaN          NaN          NaN
# 1      Brandon Allen          NaN          NaN          NaN          NaN
# 2        Mark Barron          NaN          NaN          NaN          NaN
# 3      Connor Barwin          NaN          NaN          NaN          NaN
# 4        Jamon Brown          NaN          NaN          NaN          NaN
#
#   10/08vs. SEA 10/15vs. JAX 10/22vs. ARI 11/05vs. NYG 11/12vs. HOU  \
# 0           IR           IR           IR           IR           IR
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN            Q            Q          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4            Q          NaN          NaN          NaN          NaN
#
#   11/19vs. MIN 11/26vs. NOR 12/03vs. ARI 12/10vs. PHI 12/17vs. SEA  \
# ...

# %%
#experimenting with merges 
cardinals_2015 = pd.merge(arizona_df5, ari1,how = 'left')
                               
cardinals_2015.head(10)
#successfully merges on Player column
cardinals_2016 = pd.merge(arizona_df6, ari2,how = 'left')
cardinals_2017 = pd.merge(arizona_df7, ari3,how = 'left')
cardinals_2018 = pd.merge(arizona_df8, ari4,how = 'left')
cardinals_2019 = pd.merge(arizona_df9, ari5,how = 'left')
cardinals_2020 = pd.merge(arizona_df10, ari6,how = 'left')


cardinals_2017.to_csv('../fix_data/cardinals2017.csv', index = False)
cardinals_2018.to_csv('../fix_data/cardinals2018.csv', index = False)
cardinals_2019.to_csv('../fix_data/cardinals2019.csv', index = False)
cardinals_2020.to_csv('../fix_data/cardinals2020.csv', index = False)

# %%
cardinals2016_df = pd.read_csv('../fix_data/cardinals2016.csv')
cardinals2017_df = pd.read_csv('../fix_data/cardinals2017.csv')
cardinals2018_df = pd.read_csv('../fix_data/cardinals2018.csv')
cardinals2019_df = pd.read_csv('../fix_data/cardinals2019.csv')
cardinals2020_df = pd.read_csv('../fix_data/cardinals2020.csv')

# %%
ravens_2015 = pd.merge(baltimore_df5, bal1, how = 'left')
ravens_2016 = pd.merge(baltimore_df6, bal2, how = 'left')
ravens_2017 = pd.merge(baltimore_df7, bal3, how = 'left')
ravens_2018 = pd.merge(baltimore_df8, bal4, how = 'left')
ravens_2019 = pd.merge(baltimore_df9, bal5, how = 'left')
ravens_2020 = pd.merge(baltimore_df10, bal6, how = 'left')

ravens_2015.to_csv('../fix_data/ravens2015.csv', index = False)
ravens_2016.to_csv('../fix_data/ravens2016.csv', index = False)
ravens_2017.to_csv('../fix_data/ravens2017.csv', index = False)
ravens_2018.to_csv('../fix_data/ravens2018.csv', index = False)
ravens_2019.to_csv('../fix_data/ravens2019.csv', index = False)
ravens_2020.to_csv('../fix_data/ravens2020.csv', index = False)

# %%
ravens2015_df = pd.read_csv('../fix_data/ravens2016.csv')
ravens2016_df = pd.read_csv('../fix_data/ravens2016.csv')
ravens2017_df = pd.read_csv('../fix_data/ravens2017.csv')
ravens2018_df = pd.read_csv('../fix_data/ravens2018.csv')
ravens2019_df = pd.read_csv('../fix_data/ravens2019.csv')
ravens2020_df = pd.read_csv('../fix_data/ravens2020.csv')

# %%
panthers_2015 = pd.merge(carolina_df5, car1, how = 'left')
panthers_2016 = pd.merge(carolina_df6, car2, how = 'left')
panthers_2017 = pd.merge(carolina_df7, car3, how = 'left')
panthers_2018 = pd.merge(carolina_df8, car4, how = 'left')
panthers_2019 = pd.merge(carolina_df9, car5, how = 'left')
panthers_2020 = pd.merge(carolina_df10, car6, how = 'left')

panthers_2015.to_csv('../fix_data/panthers2015.csv', index = False)
panthers_2016.to_csv('../fix_data/panthers2016.csv', index = False)
panthers_2017.to_csv('../fix_data/panthers2017.csv', index = False)
panthers_2018.to_csv('../fix_data/panthers2018.csv', index = False)
panthers_2019.to_csv('../fix_data/panthers2019.csv', index = False)
panthers_2020.to_csv('../fix_data/panthers2020.csv', index = False)

# %%
panthers2015_df = pd.read_csv('../fix_data/panthers2015.csv')
panthers2016_df = pd.read_csv('../fix_data/panthers2016.csv')
panthers2017_df = pd.read_csv('../fix_data/panthers2017.csv')
panthers2018_df = pd.read_csv('../fix_data/panthers2018.csv')
panthers2019_df = pd.read_csv('../fix_data/panthers2019.csv')
panthers2020_df = pd.read_csv('../fix_data/panthers2020.csv')

# %%
bills_2015 = pd.merge(buffalo_df5, buf1, how = 'left')
bills_2016 = pd.merge(buffalo_df6, buf2, how = 'left')
bills_2017 = pd.merge(buffalo_df7, buf3, how = 'left')
bills_2018 = pd.merge(buffalo_df8, buf4, how = 'left')
bills_2019 = pd.merge(buffalo_df9, buf5, how = 'left')
bills_2020 = pd.merge(buffalo_df10, buf6, how = 'left')

bills_2015.to_csv('../fix_data/bills2015.csv', index = False)
bills_2016.to_csv('../fix_data/bills2016.csv', index = False)
bills_2017.to_csv('../fix_data/bills2017.csv', index = False)
bills_2018.to_csv('../fix_data/bills2018.csv', index = False)
bills_2019.to_csv('../fix_data/bills2019.csv', index = False)
bills_2020.to_csv('../fix_data/bills2020.csv', index = False)

# %%
bills2015_df = pd.read_csv('../fix_data/bills2015.csv')
bills2016_df = pd.read_csv('../fix_data/bills2016.csv')
bills2017_df = pd.read_csv('../fix_data/bills2017.csv')
bills2018_df = pd.read_csv('../fix_data/bills2018.csv')
bills2019_df = pd.read_csv('../fix_data/bills2019.csv')
bills2020_df = pd.read_csv('../fix_data/bills2020.csv')

# %%
chargers_2015 = pd.merge(chargers_df5, sdg1, how = 'left')
chargers_2016 = pd.merge(chargers_df6, sdg2, how = 'left')
chargers_2017 = pd.merge(chargers_df7, sdg3, how = 'left')
chargers_2018 = pd.merge(chargers_df8, sdg4, how = 'left')
chargers_2019 = pd.merge(chargers_df9, sdg5, how = 'left')
chargers_2020 = pd.merge(chargers_df10, sdg6, how = 'left')

chargers_2015.to_csv('../fix_data/chargers2015.csv', index = False)
chargers_2016.to_csv('../fix_data/chargers2016.csv', index = False)
chargers_2017.to_csv('../fix_data/chargers2017.csv', index = False)
chargers_2018.to_csv('../fix_data/chargers2018.csv', index = False)
chargers_2019.to_csv('../fix_data/chargers2019.csv', index = False)
chargers_2020.to_csv('../fix_data/chargers2020.csv', index = False)

# %%
chargers2015_df = pd.read_csv('../fix_data/chargers2015.csv')
chargers2016_df = pd.read_csv('../fix_data/chargers2016.csv')
chargers2017_df = pd.read_csv('../fix_data/chargers2017.csv')
chargers2018_df = pd.read_csv('../fix_data/chargers2018.csv')
chargers2019_df = pd.read_csv('../fix_data/chargers2019.csv')
chargers2020_df = pd.read_csv('../fix_data/chargers2020.csv')

# %%
chicago_2015 = pd.merge(chicago_df5, chi1, how = 'left')
chicago_2016 = pd.merge(chicago_df6, chi2, how = 'left')
chicago_2017 = pd.merge(chicago_df7, chi3, how = 'left')
chicago_2018 = pd.merge(chicago_df8, chi4, how = 'left')
chicago_2019 = pd.merge(chicago_df9, chi5, how = 'left')
chicago_2020 = pd.merge(chicago_df10, chi6, how = 'left')

chicago_2015.to_csv('../fix_data/chicago2015.csv', index = False)
chicago_2016.to_csv('../fix_data/chicago2016.csv', index = False)
chicago_2017.to_csv('../fix_data/chicago2017.csv', index = False)
chicago_2018.to_csv('../fix_data/chicago2018.csv', index = False)
chicago_2019.to_csv('../fix_data/chicago2019.csv', index = False)
chicago_2020.to_csv('../fix_data/chicago2020.csv', index = False)

# %%
bears2015_df = pd.read_csv('../fix_data/chicago2015.csv')
bears2016_df = pd.read_csv('../fix_data/chicago2016.csv')
bears2017_df = pd.read_csv('../fix_data/chicago2017.csv')
bears2018_df = pd.read_csv('../fix_data/chicago2018.csv')
bears2019_df = pd.read_csv('../fix_data/chicago2019.csv')
bears2020_df = pd.read_csv('../fix_data/chicago2020.csv')

# %%
cleveland_2015 = pd.merge(cleveland_df5, cle1, how = 'left')
cleveland_2016 = pd.merge(cleveland_df6, cle2, how = 'left')
cleveland_2017 = pd.merge(cleveland_df7, cle3, how = 'left')
cleveland_2018 = pd.merge(cleveland_df8, cle4, how = 'left')
cleveland_2019 = pd.merge(cleveland_df9, cle5, how = 'left')
cleveland_2020 = pd.merge(cleveland_df10, cle6, how = 'left')

cleveland_2015.to_csv('../fix_data/browns2015.csv', index = False)
cleveland_2016.to_csv('../fix_data/browns2016.csv', index = False)
cleveland_2017.to_csv('../fix_data/browns2017.csv', index = False)
cleveland_2018.to_csv('../fix_data/browns2018.csv', index = False)
cleveland_2019.to_csv('../fix_data/browns2019.csv', index = False)
cleveland_2020.to_csv('../fix_data/browns2020.csv', index = False)

# %%
browns2015_df = pd.read_csv('../fix_data/browns2015.csv')
browns2016_df = pd.read_csv('../fix_data/browns2016.csv')
browns2017_df = pd.read_csv('../fix_data/browns2017.csv')
browns2018_df = pd.read_csv('../fix_data/browns2018.csv')
browns2019_df = pd.read_csv('../fix_data/browns2019.csv')
browns2020_df = pd.read_csv('../fix_data/browns2020.csv')

# %%
indy_2015 = pd.merge(indy5, clt1, how = 'left')
indy_2016 = pd.merge(indy6, clt2, how = 'left')
indy_2017 = pd.merge(indy7, clt3, how = 'left')
indy_2018 = pd.merge(indy8, clt4, how = 'left')
indy_2019 = pd.merge(indy9, clt5, how = 'left')
indy_2020 = pd.merge(indy10, clt6, how = 'left')

indy_2015.to_csv('../fix_data/colts2015.csv', index = False)
indy_2016.to_csv('../fix_data/colts2016.csv', index = False)
indy_2017.to_csv('../fix_data/colts2017.csv', index = False)
indy_2018.to_csv('../fix_data/colts2018.csv', index = False)
indy_2019.to_csv('../fix_data/colts2019.csv', index = False)
indy_2020.to_csv('../fix_data/colts2020.csv', index = False)

# %%
colts2015_df = pd.read_csv('../fix_data/colts2015.csv')
colts2016_df = pd.read_csv('../fix_data/colts2016.csv')
colts2017_df = pd.read_csv('../fix_data/colts2017.csv')
colts2018_df = pd.read_csv('../fix_data/colts2018.csv')
colts2019_df = pd.read_csv('../fix_data/colts2019.csv')
colts2020_df = pd.read_csv('../fix_data/colts2020.csv')

# %%
dallas_2015 = pd.merge(dallas_df5, dal1, how = 'left')
dallas_2016 = pd.merge(dallas_df6, dal2, how = 'left')
dallas_2017 = pd.merge(dallas_df7, dal3, how = 'left')
dallas_2018 = pd.merge(dallas_df8, dal4, how = 'left')
dallas_2019 = pd.merge(dallas_df9, dal5, how = 'left')
dallas_2020 = pd.merge(dallas_df10, dal6, how = 'left')

dallas_2015.to_csv('../fix_data/cowboys2015.csv', index = False)
dallas_2016.to_csv('../fix_data/cowboys2016.csv', index = False)
dallas_2017.to_csv('../fix_data/cowboys2017.csv', index = False)
dallas_2018.to_csv('../fix_data/cowboys2018.csv', index = False)
dallas_2019.to_csv('../fix_data/cowboys2019.csv', index = False)
dallas_2020.to_csv('../fix_data/cowboys2020.csv', index = False)

# %%
cowboys2015_df = pd.read_csv('../fix_data/cowboys2015.csv')
cowboys2016_df = pd.read_csv('../fix_data/cowboys2016.csv')
cowboys2017_df = pd.read_csv('../fix_data/cowboys2017.csv')
cowboys2018_df = pd.read_csv('../fix_data/cowboys2018.csv')
cowboys2019_df = pd.read_csv('../fix_data/cowboys2019.csv')
cowboys2020_df = pd.read_csv('../fix_data/cowboys2020.csv')

# %%
denver_2015 = pd.merge(denver5, den1, how = 'left')
denver_2016 = pd.merge(denver6, den2, how = 'left')
denver_2017 = pd.merge(denver7, den3, how = 'left')
denver_2018 = pd.merge(denver8, den4, how = 'left')
denver_2019 = pd.merge(denver9, den5, how = 'left')
denver_2020 = pd.merge(denver10, den6, how = 'left')

denver_2015.to_csv('../fix_data/broncos2015.csv', index = False)
denver_2016.to_csv('../fix_data/broncos2016.csv', index = False)
denver_2017.to_csv('../fix_data/broncos2017.csv', index = False)
denver_2018.to_csv('../fix_data/broncos2018.csv', index = False)
denver_2019.to_csv('../fix_data/broncos2019.csv', index = False)
denver_2020.to_csv('../fix_data/broncos2020.csv', index = False)

# %%
broncos2015_df = pd.read_csv('../fix_data/broncos2015.csv')
broncos2016_df = pd.read_csv('../fix_data/broncos2016.csv')
broncos2017_df = pd.read_csv('../fix_data/broncos2017.csv')
broncos2018_df = pd.read_csv('../fix_data/broncos2018.csv')
broncos2019_df = pd.read_csv('../fix_data/broncos2019.csv')
broncos2020_df = pd.read_csv('../fix_data/broncos2020.csv')

# %%
detroit_2015 = pd.merge(detroit5, det1, how = 'left')
detroit_2016 = pd.merge(detroit6, det2, how = 'left')
detroit_2017 = pd.merge(detroit7, det3, how = 'left')
detroit_2018 = pd.merge(detroit8, det4, how = 'left')
detroit_2019 = pd.merge(detroit9, det5, how = 'left')
detroit_2020 = pd.merge(detroit10, det6, how = 'left')

detroit_2015.to_csv('../fix_data/lions2015.csv', index = False)
detroit_2016.to_csv('../fix_data/lions2016.csv', index = False)
detroit_2017.to_csv('../fix_data/lions2017.csv', index = False)
detroit_2018.to_csv('../fix_data/lions2018.csv', index = False)
detroit_2019.to_csv('../fix_data/lions2019.csv', index = False)
detroit_2020.to_csv('../fix_data/lions2020.csv', index = False)

# %%
lions2015_df = pd.read_csv('../fix_data/lions2015.csv')
lions2016_df = pd.read_csv('../fix_data/lions2016.csv')
lions2017_df = pd.read_csv('../fix_data/lions2017.csv')
lions2018_df = pd.read_csv('../fix_data/lions2018.csv')
lions2019_df = pd.read_csv('../fix_data/lions2019.csv')
lions2020_df = pd.read_csv('../fix_data/lions2020.csv')

# %%
greenbay_2015 = pd.merge(greenbay5, gnb1, how = 'left')
greenbay_2016 = pd.merge(greenbay6, gnb2, how = 'left')
greenbay_2017 = pd.merge(greenbay7, gnb3, how = 'left')
greenbay_2018 = pd.merge(greenbay8, gnb4, how = 'left')
greenbay_2019 = pd.merge(greenbay9, gnb5, how = 'left')
greenbay_2020 = pd.merge(greenbay10, gnb6, how = 'left')

greenbay_2015.to_csv('../fix_data/packers2015.csv', index = False)
greenbay_2016.to_csv('../fix_data/packers2016.csv', index = False)
greenbay_2017.to_csv('../fix_data/packers2017.csv', index = False)
greenbay_2018.to_csv('../fix_data/packers2018.csv', index = False)
greenbay_2019.to_csv('../fix_data/packers2019.csv', index = False)
greenbay_2020.to_csv('../fix_data/packers2020.csv', index = False)

# %%
packers2015_df = pd.read_csv('../fix_data/packers2015.csv')
packers2016_df = pd.read_csv('../fix_data/packers2016.csv')
packers2017_df = pd.read_csv('../fix_data/packers2017.csv')
packers2018_df = pd.read_csv('../fix_data/packers2018.csv')
packers2019_df = pd.read_csv('../fix_data/packers2019.csv')
packers2020_df = pd.read_csv('../fix_data/packers2020.csv')

# %%
houston_2015 = pd.merge(houston5, htx1, how = 'left')
houston_2016 = pd.merge(houston6, htx2, how = 'left')
houston_2017 = pd.merge(houston7, htx3, how = 'left')
houston_2018 = pd.merge(houston8, htx4, how = 'left')
houston_2019 = pd.merge(houston9, htx5, how = 'left')
houston_2020 = pd.merge(houston10, htx6, how = 'left')

houston_2015.to_csv('../fix_data/texans2015.csv', index = False)
houston_2016.to_csv('../fix_data/texans2016.csv', index = False)
houston_2017.to_csv('../fix_data/texans2017.csv', index = False)
houston_2018.to_csv('../fix_data/texans2018.csv', index = False)
houston_2019.to_csv('../fix_data/texans2019.csv', index = False)
houston_2020.to_csv('../fix_data/texans2020.csv', index = False)

# %%
texans2015_df = pd.read_csv('../fix_data/texans2015.csv')
texans2016_df = pd.read_csv('../fix_data/texans2016.csv')
texans2017_df = pd.read_csv('../fix_data/texans2017.csv')
texans2018_df = pd.read_csv('../fix_data/texans2018.csv')
texans2019_df = pd.read_csv('../fix_data/texans2019.csv')
texans2020_df = pd.read_csv('../fix_data/texans2020.csv')

# %%
jacksonville_2015 = pd.merge(jacksonville5, jax1, how = 'left')
jacksonville_2016 = pd.merge(jacksonville6, jax2, how = 'left')
jacksonville_2017 = pd.merge(jacksonville7, jax3, how = 'left')
jacksonville_2018 = pd.merge(jacksonville8, jax4, how = 'left')
jacksonville_2019 = pd.merge(jacksonville9, jax5, how = 'left')
jacksonville_2020 = pd.merge(jacksonville10, jax6, how = 'left')

jacksonville_2015.to_csv('../fix_data/jaguars2015.csv', index = False)
jacksonville_2016.to_csv('../fix_data/jaguars2016.csv', index = False)
jacksonville_2017.to_csv('../fix_data/jaguars2017.csv', index = False)
jacksonville_2018.to_csv('../fix_data/jaguars2018.csv', index = False)
jacksonville_2019.to_csv('../fix_data/jaguars2019.csv', index = False)
jacksonville_2020.to_csv('../fix_data/jaguars2020.csv', index = False)

# %%
jaguars2015_df = pd.read_csv('../fix_data/jaguars2015.csv')
jaguars2016_df = pd.read_csv('../fix_data/jaguars2016.csv')
jaguars2017_df = pd.read_csv('../fix_data/jaguars2017.csv')
jaguars2018_df = pd.read_csv('../fix_data/jaguars2018.csv')
jaguars2019_df = pd.read_csv('../fix_data/jaguars2019.csv')
jaguars2020_df = pd.read_csv('../fix_data/jaguars2020.csv')

# %%
kansascity_2015 = pd.merge(kansascity5, kan1, how = 'left')
kansascity_2016 = pd.merge(kansascity6, kan2, how = 'left')
kansascity_2017 = pd.merge(kansascity7, kan3, how = 'left')
kansascity_2018 = pd.merge(kansascity8, kan4, how = 'left')
kansascity_2019 = pd.merge(kansascity9, kan5, how = 'left')
kansascity_2020 = pd.merge(kansascity10, kan6, how = 'left')

kansascity_2015.to_csv('../fix_data/chiefs2015.csv', index = False)
kansascity_2016.to_csv('../fix_data/chiefs2016.csv', index = False)
kansascity_2017.to_csv('../fix_data/chiefs2017.csv', index = False)
kansascity_2018.to_csv('../fix_data/chiefs2018.csv', index = False)
kansascity_2019.to_csv('../fix_data/chiefs2019.csv', index = False)
kansascity_2020.to_csv('../fix_data/chiefs2020.csv', index = False)

# %%
chiefs2015_df = pd.read_csv('../fix_data/chiefs2015.csv')
chiefs2016_df = pd.read_csv('../fix_data/chiefs2016.csv')
chiefs2017_df = pd.read_csv('../fix_data/chiefs2017.csv')
chiefs2018_df = pd.read_csv('../fix_data/chiefs2018.csv')
chiefs2019_df = pd.read_csv('../fix_data/chiefs2019.csv')
chiefs2020_df = pd.read_csv('../fix_data/chiefs2020.csv')

# %%
miami_2015 = pd.merge(miami5, mia1, how = 'left')
miami_2016 = pd.merge(miami6, mia2, how = 'left')
miami_2017 = pd.merge(miami7, mia3, how = 'left')
miami_2018 = pd.merge(miami8, mia4, how = 'left')
miami_2019 = pd.merge(miami9, mia5, how = 'left')
miami_2020 = pd.merge(miami10, mia6, how = 'left')

miami_2015.to_csv('../fix_data/dolphins2015.csv', index = False)
miami_2016.to_csv('../fix_data/dolphins2016.csv', index = False)
miami_2017.to_csv('../fix_data/dolphins2017.csv', index = False)
miami_2018.to_csv('../fix_data/dolphins2018.csv', index = False)
miami_2019.to_csv('../fix_data/dolphins2019.csv', index = False)
miami_2020.to_csv('../fix_data/dolphins2020.csv', index = False)

# %%
dolphins2015_df = pd.read_csv('../fix_data/dolphins2015.csv')
dolphins2016_df = pd.read_csv('../fix_data/dolphins2016.csv')
dolphins2017_df = pd.read_csv('../fix_data/dolphins2017.csv')
dolphins2018_df = pd.read_csv('../fix_data/dolphins2018.csv')
dolphins2019_df = pd.read_csv('../fix_data/dolphins2019.csv')
dolphins2020_df = pd.read_csv('../fix_data/dolphins2020.csv')

# %%
minnesota_2015 = pd.merge(minnesota5, minn1, how = 'left')
minnesota_2016 = pd.merge(minnesota6, minn2, how = 'left')
minnesota_2017 = pd.merge(minnesota7, minn3, how = 'left')
minnesota_2018 = pd.merge(minnesota8, minn4, how = 'left')
minnesota_2019 = pd.merge(minnesota9, minn5, how = 'left')
minnesota_2020 = pd.merge(minnesota10, minn6, how = 'left')

minnesota_2015.to_csv('../fix_data/vikings2015.csv', index = False)
minnesota_2016.to_csv('../fix_data/vikings2016.csv', index = False)
minnesota_2017.to_csv('../fix_data/vikings2017.csv', index = False)
minnesota_2018.to_csv('../fix_data/vikings2018.csv', index = False)
minnesota_2019.to_csv('../fix_data/vikings2019.csv', index = False)
minnesota_2020.to_csv('../fix_data/vikings2020.csv', index = False)

# %%
vikings2015_df = pd.read_csv('../fix_data/vikings2015.csv')
vikings2016_df = pd.read_csv('../fix_data/vikings2016.csv')
vikings2017_df = pd.read_csv('../fix_data/vikings2017.csv')
vikings2018_df = pd.read_csv('../fix_data/vikings2018.csv')
vikings2019_df = pd.read_csv('../fix_data/vikings2019.csv')
vikings2020_df = pd.read_csv('../fix_data/vikings2020.csv')

# %%
newengland_2015 = pd.merge(newengland5, new1, how = 'left')
newengland_2016 = pd.merge(newengland6, new2, how = 'left')
newengland_2017 = pd.merge(newengland7, new3, how = 'left')
newengland_2018 = pd.merge(newengland8, new4, how = 'left')
newengland_2019 = pd.merge(newengland9, new5, how = 'left')
newengland_2020 = pd.merge(newengland10, new6, how = 'left')

newengland_2015.to_csv('../fix_data/patriots2015.csv', index = False)
newengland_2016.to_csv('../fix_data/patriots2016.csv', index = False)
newengland_2017.to_csv('../fix_data/patriots2017.csv', index = False)
newengland_2018.to_csv('../fix_data/patriots2018.csv', index = False)
newengland_2019.to_csv('../fix_data/patriots2019.csv', index = False)
newengland_2020.to_csv('../fix_data/patriots2020.csv', index = False)

# %%
patriots2015_df = pd.read_csv('../fix_data/patriots2015.csv')
patriots2016_df = pd.read_csv('../fix_data/patriots2016.csv')
patriots2017_df = pd.read_csv('../fix_data/patriots2017.csv')
patriots2018_df = pd.read_csv('../fix_data/patriots2018.csv')
patriots2019_df = pd.read_csv('../fix_data/patriots2019.csv')
patriots2020_df = pd.read_csv('../fix_data/patriots2020.csv')

# %%
nyj_2015 = pd.merge(nyj5, nyj_positions1, how = 'left')
nyj_2016 = pd.merge(nyj6, nyj_positions2, how = 'left')
nyj_2017 = pd.merge(nyj7, nyj_positions3, how = 'left')
nyj_2018 = pd.merge(nyj8, nyj_positions4, how = 'left')
nyj_2019 = pd.merge(nyj9, nyj_positions5, how = 'left')
nyj_2020 = pd.merge(nyj10, nyj_positions6, how = 'left')

nyj_2015.to_csv('../fix_data/jets2015.csv', index = False)
nyj_2016.to_csv('../fix_data/jets2016.csv', index = False)
nyj_2017.to_csv('../fix_data/jets2017.csv', index = False)
nyj_2018.to_csv('../fix_data/jets2018.csv', index = False)
nyj_2019.to_csv('../fix_data/jets2019.csv', index = False)
nyj_2020.to_csv('../fix_data/jets2020.csv', index = False)

# %%
jets2015_df = pd.read_csv('../fix_data/jets2015.csv')
jets2016_df = pd.read_csv('../fix_data/jets2016.csv')
jets2017_df = pd.read_csv('../fix_data/jets2017.csv')
jets2018_df = pd.read_csv('../fix_data/jets2018.csv')
jets2019_df = pd.read_csv('../fix_data/jets2019.csv')
jets2020_df = pd.read_csv('../fix_data/jets2020.csv')

# %%
nyg_2015 = pd.merge(nyg5, nyg_positions1, how = 'left')
nyg_2016 = pd.merge(nyg6, nyg_positions2, how = 'left')
nyg_2017 = pd.merge(nyg7, nyg_positions3, how = 'left')
nyg_2018 = pd.merge(nyg8, nyg_positions4, how = 'left')
nyg_2019 = pd.merge(nyg9, nyg_positions5, how = 'left')
nyg_2020 = pd.merge(nyg10, nyg_positions6, how = 'left')

nyg_2015.to_csv('../fix_data/giants2015.csv', index = False)
nyg_2016.to_csv('../fix_data/giants2016.csv', index = False)
nyg_2017.to_csv('../fix_data/giants2017.csv', index = False)
nyg_2018.to_csv('../fix_data/giants2018.csv', index = False)
nyg_2019.to_csv('../fix_data/giants2019.csv', index = False)
nyg_2020.to_csv('../fix_data/giants2020.csv', index = False)

# %%
giants2015_df = pd.read_csv('../fix_data/giants2015.csv')
giants2016_df = pd.read_csv('../fix_data/giants2016.csv')
giants2017_df = pd.read_csv('../fix_data/giants2017.csv')
giants2018_df = pd.read_csv('../fix_data/giants2018.csv')
giants2019_df = pd.read_csv('../fix_data/giants2019.csv')
giants2020_df = pd.read_csv('../fix_data/giants2020.csv')

# %%
pittsburgh_2015 = pd.merge(pittsburgh5, pit1, how = 'left')
pittsburgh_2016 = pd.merge(pittsburgh6, pit2, how = 'left')
pittsburgh_2017 = pd.merge(pittsburgh7, pit3, how = 'left')
pittsburgh_2018 = pd.merge(pittsburgh8, pit4, how = 'left')
pittsburgh_2019 = pd.merge(pittsburgh9, pit5, how = 'left')
pittsburgh_2020 = pd.merge(pittsburgh10, pit6, how = 'left')

pittsburgh_2015.to_csv('../fix_data/steelers2015.csv', index = False)
pittsburgh_2016.to_csv('../fix_data/steelers2016.csv', index = False)
pittsburgh_2017.to_csv('../fix_data/steelers2017.csv', index = False)
pittsburgh_2018.to_csv('../fix_data/steelers2018.csv', index = False)
pittsburgh_2019.to_csv('../fix_data/steelers2019.csv', index = False)
pittsburgh_2020.to_csv('../fix_data/steelers2020.csv', index = False)

# %%
steelers2015_df = pd.read_csv('../fix_data/steelers2015.csv')
steelers2016_df = pd.read_csv('../fix_data/steelers2016.csv')
steelers2017_df = pd.read_csv('../fix_data/steelers2017.csv')
steelers2018_df = pd.read_csv('../fix_data/steelers2018.csv')
steelers2019_df = pd.read_csv('../fix_data/steelers2019.csv')
steelers2020_df = pd.read_csv('../fix_data/steelers2020.csv')

# %%
rams_2015 = pd.merge(rams5, ram1, how = 'left')
rams_2016 = pd.merge(rams6, ram2, how = 'left')
rams_2017 = pd.merge(rams7, ram3, how = 'left')
rams_2018 = pd.merge(rams8, ram4, how = 'left')
rams_2019 = pd.merge(rams9, ram5, how = 'left')
rams_2020 = pd.merge(rams10, ram6, how = 'left')

rams_2015.to_csv('../fix_data/rams2015.csv', index = False)
rams_2016.to_csv('../fix_data/rams2016.csv', index = False)
rams_2017.to_csv('../fix_data/rams2017.csv', index = False)
rams_2018.to_csv('../fix_data/rams2018.csv', index = False)
rams_2019.to_csv('../fix_data/rams2019.csv', index = False)
rams_2020.to_csv('../fix_data/rams2020.csv', index = False)

# %%
rams2015_df = pd.read_csv('../fix_data/rams2015.csv')
rams2016_df = pd.read_csv('../fix_data/rams2016.csv')
rams2017_df = pd.read_csv('../fix_data/rams2017.csv')
rams2018_df = pd.read_csv('../fix_data/rams2018.csv')
rams2019_df = pd.read_csv('../fix_data/rams2019.csv')
rams2020_df = pd.read_csv('../fix_data/rams2020.csv')

# %%
rams2017_df.head()
# Out:
#              Player  09/10vs. IND 09/17vs. WAS 09/21vs. SFO 10/01vs. DAL  \
# 0  Maurice Alexander          NaN          NaN          NaN          NaN
# 1      Brandon Allen          NaN          NaN          NaN          NaN
# 2        Mark Barron          NaN          NaN          NaN          NaN
# 3      Connor Barwin          NaN          NaN          NaN          NaN
# 4        Jamon Brown          NaN          NaN          NaN          NaN
#
#   10/08vs. SEA 10/15vs. JAX 10/22vs. ARI 11/05vs. NYG 11/12vs. HOU  ...     G  \
# 0           IR           IR           IR           IR           IR  ...   NaN
# 1          NaN          NaN          NaN          NaN          NaN  ...   NaN
# 2          NaN            Q            Q          NaN          NaN  ...  14.0
# 3          NaN          NaN          NaN          NaN          NaN  ...  14.0
# 4            Q          NaN          NaN          NaN          NaN  ...  16.0
#
# ...

# %%
oakland_2015 = pd.merge(oakland5, rai1, how = 'left')
oakland_2016 = pd.merge(oakland6, rai2, how = 'left')
oakland_2017 = pd.merge(oakland7, rai3, how = 'left')
oakland_2018 = pd.merge(oakland8, rai4, how = 'left')
oakland_2019 = pd.merge(oakland9, rai5, how = 'left')
oakland_2020 = pd.merge(oakland10, rai6, how = 'left')


oakland_2015.to_csv('../fix_data/raiders2015.csv', index = False)
oakland_2016.to_csv('../fix_data/raiders2016.csv', index = False)
oakland_2017.to_csv('../fix_data/raiders2017.csv', index = False)
oakland_2018.to_csv('../fix_data/raiders2018.csv', index = False)
oakland_2019.to_csv('../fix_data/raiders2019.csv', index = False)
oakland_2020.to_csv('../fix_data/raiders2020.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-107-77c54f47c0d4> in <module>
#       4 oakland_2018 = pd.merge(oakland8, rai4, how = 'left')
#       5 oakland_2019 = pd.merge(oakland9, rai5, how = 'left')
# ----> 6 oakland_2020 = pd.merge(oakland10, rai6, how = 'left')
#       7
#       8
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     618             warnings.warn(msg, UserWarning)
#     619
# ...

# %%
raiders2015_df = pd.read_csv('../fix_data/raiders2015.csv')
raiders2016_df = pd.read_csv('../fix_data/raiders2016.csv')
raiders2017_df = pd.read_csv('../fix_data/raiders2017.csv')
raiders2018_df = pd.read_csv('../fix_data/raiders2018.csv')
raiders2019_df = pd.read_csv('../fix_data/raiders2019.csv')
raiders2020_df = pd.read_csv('../fix_data/raiders2020.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-108-fe0de03eceed> in <module>
#       4 raiders2018_df = pd.read_csv('../fix_data/raiders2018.csv')
#       5 raiders2019_df = pd.read_csv('../fix_data/raiders2019.csv')
# ----> 6 raiders2020_df = pd.read_csv('../fix_data/raiders2020.csv')
#
# ...

# %%
steelers2020_df.head()
# Out:
#           Player  09/14vs. NYG 09/20vs. DEN 09/27vs. HOU 10/11vs. PHI  \
# 0    Marcus Allen          NaN          NaN          NaN            O
# 1    Tyson Alualu          NaN          NaN          NaN          NaN
# 2     Zach Banner          NaN           IR           IR           IR
# 3    Isaiah Buggs          NaN          NaN          NaN          NaN
# 4  Devin Bush Jr.          NaN          NaN          NaN          NaN
#
#   10/18vs. CLE 10/25vs. TEN 11/01vs. BAL 11/08vs. DAL 11/15vs. CIN  ...     G  \
# 0          NaN          NaN          NaN          NaN          NaN  ...  12.0
# 1          NaN          NaN          NaN            O          NaN  ...  12.0
# 2           IR           IR           IR           IR           IR  ...   NaN
# 3          NaN          NaN          NaN          NaN            Q  ...   9.0
# 4          NaN           IR           IR           IR           IR  ...   NaN
#
#     GS     Wt          Ht  College/Univ   BirthDate  Yrs  AV  \
# ...

# %%
falcons_2015 = pd.merge(atlanta_df5, atl1, how = 'left')
falcons_2016 = pd.merge(atlanta_df6, atl2, how = 'left')
falcons_2017 = pd.merge(atlanta_df7, atl3, how = 'left')
falcons_2018 = pd.merge(atlanta_df8, atl4, how = 'left')
falcons_2019 = pd.merge(atlanta_df9, atl5, how = 'left')
falcons_2020 = pd.merge(atlanta_df10, atl6, how = 'left')

falcons_2017
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-13-8019facd35ba> in <module>
#       3 falcons_2017 = pd.merge(atlanta_df7, atl3, how = 'left')
#       4 falcons_2018 = pd.merge(atlanta_df8, atl4, how = 'left')
# ----> 5 falcons_2019 = pd.merge(atlanta_df9, atl5, how = 'left')
#       6 falcons_2020 = pd.merge(atlanta_df10, atl6, how = 'left')
#       7
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
falcons_2018
# Out:
#                Player  09/06vs. PHI 09/16vs. CAR 09/23vs. NOR 09/30vs. CIN  \
# 0        Robert Alford          NaN          NaN          NaN          NaN
# 1        Ricardo Allen          NaN          NaN          NaN           IR
# 2        Justin Bethel          NaN          NaN          NaN            O
# 3          Matt Bryant          NaN          NaN          NaN          NaN
# 4      Devonta Freeman          NaN            O            O            O
# 5        Brandon Fusco          NaN          NaN          NaN          NaN
# 6         Russell Gage          NaN            O          NaN          NaN
# 7          Ben Garland            O            O          NaN          NaN
# 8          Josh Harris            Q          NaN          NaN          NaN
# 9        Grady Jarrett          NaN          NaN          NaN          NaN
# 10         Deion Jones          NaN           IR           IR           IR
# ...

# %%
falcons_2015.to_csv('../fix_data/falcons2015.csv', index = False)                        
falcons_2016.to_csv('../fix_data/falcons2016.csv', index = False)
falcons_2017.to_csv('../fix_data/falcons2017.csv', index = False)
falcons_2018.to_csv('../fix_data/falcons2018.csv', index = False)
falcons_2019.to_csv('../fix_data/falcons2019.csv', index = False)
falcons_2020.to_csv('../fix_data/falcons2020.csv', index = False)

# %%
atlanta_df5

# %%
cardinals2020_df

# %%
cardinals_2015.shape

# %%
cardinals_2015 = cardinals_2015.drop(columns=[ 'No.', 'G', 'GS', 'Wt', 'Ht', 'College/Univ', 'Yrs','AV', 'BirthDate', "Drafted (tm/rnd/yr)"],axis = 1)

cardinals_2015.head()

# %%
cardinals_2015.head()

# %%
cardinals_2015 = cardinals_2015.rename(columns = {"09/13vs. NOR" :'Week 1', '09/20vs. CHI':'Week 2', '09/27vs. SFO':'Week 3','10/04vs. STL':'Week 4', '10/11vs. DET':'Week 5','10/18vs. PIT':'Week 6', '10/26vs. BAL':'Week 7','11/01vs. CLE': 'Week 8', '11/15vs. SEA':'Week 9', '11/22vs. CIN':'Week 10', '11/29vs. SFO':'Week 11','12/06vs. STL':'Week 12', '12/10vs. MIN':'Week 13', '12/20vs. PHI':'Week 14','12/27vs. GNB':'Week 15', '01/03vs. SEA':'Week 16'  })

# %%
cardinals_2016.head()

# %%
cardinals_2015 = cardinals_2015.rename(columns = {"09/11vs. NWE" :'Week 1', '09/18vs. TAM':'Week 2', '09/27vs. SFO':'Week 3','10/04vs. STL':'Week 4', '10/11vs. DET':'Week 5','10/18vs. PIT':'Week 6', '10/26vs. BAL':'Week 7','11/01vs. CLE': 'Week 8', '11/15vs. SEA':'Week 9', '11/22vs. CIN':'Week 10', '11/29vs. SFO':'Week 11','12/06vs. STL':'Week 12', '12/10vs. MIN':'Week 13', '12/20vs. PHI':'Week 14','12/27vs. GNB':'Week 15', '01/03vs. SEA':'Week 16'  })

# %%
cardinals_2015 = cardinals_2015.drop(columns=['01/16vs. GNB', '01/24vs. CAR'])
cardinals_2015.head()

# %%
cardinals_2015.shape

# %%
cardinals_2015.to_csv('../clean_data/cardinals2015.csv', index = False)

# %%
cardinals_2016[(cardinals_2016=="IR").any(1)]

# %%
cardinals_2016

# %%
saints_2020 =  pd.merge(neworleans10, nor6,how = 'inner')
                               
saints_2020
